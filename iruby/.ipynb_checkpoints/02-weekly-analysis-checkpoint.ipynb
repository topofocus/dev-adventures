# %%
require_relative 'db-console'
#Arcade::Database.logger.level =  Logger::ERROR
# Out:
# "<h2>Arcade Stock Database </h2>"
# "<h3>Production Environment </h3>"
# true

# %%
spx = Contract.first
# Out:
# "<span style=\"color: #50953DFF\"><b>Index</b><Index</b>[#313:0] : {0->}{->0}</span>< SPX, USD, CBOE >"

# %% [markdown]
# ### Anfangs- und Enddaten sammeln

# %%
start_dates = Ohlc.start_entry(spx).map &:datum
end_dates = Ohlc.last_entry(spx).map &:datum
trades, vola = start_dates.zip end_dates

IRuby.display IRuby.html ["<h3>Start und Enddatenpunkte </h3>",
                 "<tt>trades: #{ trades.join " ---> "}</tt> ",
                 "<tt>vola:   #{ vola.join " ---> "} </tt>"]
# Out:
# "<h3>Start und Enddatenpunkte </h3>"
# "<tt>trades: 2004-03-04 ---> 2023-11-07</tt> "
# "<tt>vola:   2006-01-06 ---> 2023-11-07 </tt>"

# %% [markdown]
# ### Freitage als Startpunkte definieren

# %%
select_all_fridays = ->(v){ (v).select{|x| x.wday == 5}}

all_fridays= select_all_fridays[ Vola.start_entry(spx).first.datum .. Vola.last_entry(spx).first.datum  ]

IRuby.display IRuby.html "<b>all_fridays</b> enthält <b>#{all_fridays.size}</b> Datensätze"
# Out:
# "<b>all_fridays</b> enthält <b>931</b> Datensätze"

# %% [markdown]
# ### Für alle Datensätze die Preisdifferenz von 28 Tagen ermitteln.
# (Bezug: close)

# %%
differences = all_fridays.map do | f |
  start_node = f.to_tg.ohlc_bar( spx ){ Tg::HasTrades }
  vola = f.to_tg.ohlc_bar( spx ){ Tg::HasVola }
  next if start_node.nil? || vola.nil?
  last_node = (f+28).to_tg.ohlc_bar( spx ){ Tg::HasTrades }
  next if last_node.nil?
  { date: f, difference: last_node.close - start_node.close, vola: vola.close, 
    norm_diff: (last_node.close - start_node.close)/ start_node.close }
end.compact
IRuby.display IRuby.table differences
# Out:
# "<table><tr><th>date</th><th>difference</th><th>vola</th><th>norm_diff</th></tr><tr><td>2006-01-06</td><td>-21.309999999999945</td><td>0.15874508</td><td>-0.01658210906374498</td></tr><tr><td>2006-01-13</td><td>-20.460000000000036</td><td>0.1000094</td><td>-0.015891879296283377</td></tr><tr><td>2006-01-20</td><td>25.63000000000011</td><td>0.12540861</td><td>0.020321110009910888</td></tr><tr><td>2006-01-27</td><td>6.180000000000064</td><td>0.1063592</td><td>0.004814996610803406</td></tr><tr><td>2006-02-03</td><td>23.210000000000036</td><td>0.11747136</td><td>0.018365102349245564</td></tr><tr><td>2006-02-10</td><td>14.759999999999991</td><td>0.11429646</td><td>0.011649657850496051</td></tr><tr><td>2006-02-17</td><td>20.199999999999818</td><td>0.10159685</td><td>0.01569687927390263</td></tr><tr><td colspan='4'>&#8942;</td></tr><tr><td>2023-08-25</td><td>-85.64999999999964</td><td>0.13017096</td><td>-0.019440680389766832</td></tr><tr><td>2023-09-01</td><td>-227.72000000000025</td><td>0.1063592</td><td>-0.05042772328971587</td></tr><tr><td>2023-09-08</td><td>-148.98999999999978</td><td>0.11588391</td><td>-0.0334246403244875</td></tr><tr><td>2023-09-15</td><td>-122.53999999999996</td><td>0.11270901</td><td>-0.027535098599651253</td></tr><tr><td>2023-09-22</td><td>-95.90000000000055</td><td>0.14287057</td><td>-0.022198765757883116</td></tr><tr><td>2023-09-29</td><td>-170.6800000000003</td><td>0.15080782</td><td>-0.03980364034934301</td></tr><tr><td>2023-10-06</td><td>49.840000000000146</td><td>0.15080782</td><td>0.011567831031681594</td></tr></table>"

# %%
Vega.lite 
  .data( differences )
  .title( text: "28DTE Kursdifferenzen ",
         color: "navy",
        fontSize: 22 ,
  		 align: "center",
  		anchor: "middle",
  			dy: -1,
      baseline: "middle",
  	  subtitle: "S&P 500  (normiert)",
 subtitleColor: "navy", 
subtitleFontSize: 18,
subtitlePadding: 5)
  .resolve( scale: { y: "independent"})
  .layer( [ 
         { mark:{ type: "line", interpolate: "cardinal", color: '#c2410c'},
           encoding: { x:{ field: "date", type: "temporal",
                           title: '' },
                       y:{ field: 'norm_diff', type: 'quantitative',
                           title: 'Norm. Preisdifferenz 28 Tage',
                           axis: { orient: 'left',titleColor:  '#c2410c'},
                           scale: { zero: false} }           }
          },
          { mark:{ type: "line", interpolate: "cardinal", color: '#0d9488'},
           encoding: { x:{ field: "date", type: "temporal"},
                       y:{ field: 'vola', type: 'quantitative',
                           title: 'Implied Volatiltiy',
                           axis: { orient: 'right', titleColor:  '#0d9488'},
                           scale: { zero: false} }           }
          }
          ])
# Out:
# #<Vega::LiteChart:0x00007f7768550b18 @schema="https://vega.github.io/schema/vega-lite/v5.json", @spec={"$schema"=>"https://vega.github.io/schema/vega-lite/v5.json", "width"=>"container", "height"=>"container", "data"=>{:values=>}, "title"=>{:text=>"28DTE Kursdifferenzen ", :color=>"navy", :fontSize=>22, :align=>"center", :anchor=>"middle", :dy=>-1, :baseline=>"middle", :subtitle=>"S&P 500  (normiert)", :subtitleColor=>"navy", :subtitleFontSize=>18, :subtitlePadding=>5}, "resolve"=>{:scale=>{:y=>"independent"}}, "layer"=>}>

# %%
Vega.lite 
  .data( differences )
  .title( text: "28DTE Kursdifferenzen ",
         color: "navy",
        fontSize: 22 ,
  		 align: "center",
  		anchor: "middle",
  			dy: -1,
      baseline: "middle",
  	  subtitle: "S&P 500  (normiert)",
 subtitleColor: "navy", 
subtitleFontSize: 18,
subtitlePadding: 5)
   .vconcat( [ {
     width: 850,
     resolve: { scale: { y: "independent"}},
     layer:  [ 
         { mark:{ type: "line", interpolate: "cardinal", color: '#c2410c'},
           encoding: { x:{ field: "date",
                            type: "temporal",
                           scale: { domain: { param: "brush" }},
                           title: '' },
                       y:{ field: 'norm_diff', type: 'quantitative',
                           title: 'Norm. Preisdifferenz 28 Tage',
                           axis: { orient: 'left',titleColor:  '#c2410c', grid: true},
                           scale: { zero: false} }           }
          },
      
          { mark:{ type: "line", interpolate: "cardinal", color: '#0d9488'},
           encoding: { x:{ field: "date", 
                           type: "temporal", 
                           scale: { domain: { param: "brush" }},
                          },
                       y:{ field: 'vola', type: 'quantitative',
                           title: 'Implied Volatiltiy',
                           axis: { orient: 'right', titleColor:  '#0d9488'},
                           scale: { zero: false} }           }
          }
          ] },
            { 
       width: 850,
      height: 60,
        mark: { type: "line", interpolate: "cardinal", color: '#c2410c'},
      params: [
                { name: "brush",
                select: { type: "interval", encodings: ["x"]}
                 }],
    encoding: { x:{ field: "date", type: "temporal", title: '' },
                y:{ field: 'norm_diff', type: 'quantitative',
            title: '28DTE',
             axis: { orient: 'left',titleColor:  '#c2410c'},
            scale: { zero: false} }           }
           }
       
             ])
# Out:
# #<Vega::LiteChart:0x00007f7738d94f48 @schema="https://vega.github.io/schema/vega-lite/v5.json", @spec={"$schema"=>"https://vega.github.io/schema/vega-lite/v5.json", "width"=>"container", "height"=>"container", "data"=>{:values=>}, "title"=>{:text=>"28DTE Kursdifferenzen ", :color=>"navy", :fontSize=>22, :align=>"center", :anchor=>"middle", :dy=>-1, :baseline=>"middle", :subtitle=>"S&P 500  (normiert)", :subtitleColor=>"navy", :subtitleFontSize=>18, :subtitlePadding=>5}, "vconcat"=>}>

# %%
s= Polars::DataFrame.new( Vola.start_entry(spx).vector(0).first.map do |y|
   { date: y.datum, ref_vola: y.wap} 
  end )
# Out:
# shape: (4478, 2)
# ┌────────────┬──────────┐
# │ date       ┆ ref_vola │
# │ ---        ┆ ---      │
# │ date       ┆ f64      │
# ╞════════════╪══════════╡
# │ 2006-01-06 ┆ 0.158745 │
# │ 2006-01-09 ┆ 0.1062   │
# │ 2006-01-10 ┆ 0.105692 │
# │ 2006-01-11 ┆ 0.105169 │
# │ ...        ┆ ...      │
# │ 2023-11-02 ┆ 0.14722  │
# │ 2023-11-03 ┆ 0.132997 │
# │ 2023-11-06 ┆ 0.128552 │
# │ 2023-11-07 ┆ 0.127107 │
# └────────────┴──────────┘

# %%
d= differences.find_all{|y| y[:norm_diff] > 0.088 || y[:norm_diff] < -0.068 }
IRuby.display "Anzahl: #{d.size}"
d << { date: Date.today, min: -0.07, max: 0.09, difference: 0, vola: 0, norm_diff: 0}
IRuby.display IRuby.table d
# Out:
# "Anzahl: 64"
# "<table><tr><th>date</th><th>difference</th><th>vola</th><th>norm_diff</th><th>min</th><th>max</th></tr><tr><td>2007-10-12</td><td>-109.50999999999999</td><td>0.16033253</td><td>-0.07012005762766127</td><td></td><td></td></tr><tr><td>2007-12-21</td><td>-159.3599999999999</td><td>0.17144468</td><td>-0.10730807302012693</td><td></td><td></td></tr><tr><td>2007-12-28</td><td>-147.15999999999985</td><td>0.1968439</td><td>-0.09959461014219091</td><td></td><td></td></tr><tr><td>2008-05-30</td><td>-119.01999999999998</td><td>0.15874508</td><td>-0.08509999356494755</td><td></td><td></td></tr><tr><td>2008-06-13</td><td>-119.72000000000003</td><td>0.1968439</td><td>-0.08803717975115452</td><td></td><td></td></tr><tr><td>2008-09-05</td><td>-142.5999999999999</td><td>0.21430586</td><td>-0.1148037226676971</td><td></td><td></td></tr><tr><td>2008-09-12</td><td>-348.31000000000006</td><td>0.24764232</td><td>-0.27815177722942275</td><td></td><td></td></tr><tr><td colspan='6'>&#8942;</td></tr><tr><td>2022-08-19</td><td>-355.14999999999964</td><td>0.18096939</td><td>-0.0839899916754956</td><td></td><td></td></tr><tr><td>2022-08-26</td><td>-364.42999999999984</td><td>0.22859291</td><td>-0.0898128477989777</td><td></td><td></td></tr><tr><td>2022-09-02</td><td>-338.6400000000003</td><td>0.23494272</td><td>-0.08629397644396658</td><td></td><td></td></tr><tr><td>2022-09-09</td><td>-427.7000000000003</td><td>0.20478115</td><td>-0.1051542032178121</td><td></td><td></td></tr><tr><td>2022-09-16</td><td>-290.25999999999976</td><td>0.24605487</td><td>-0.0749381023563703</td><td></td><td></td></tr><tr><td>2022-10-14</td><td>409.8599999999997</td><td>0.2936784</td><td>0.11438794106729694</td><td></td><td></td></tr><tr><td>2023-11-19</td><td>0</td><td>0</td><td>0</td><td>-0.07</td><td>0.09</td></tr></table>"

# %%
t = Polars::DataFrame.new d
# Out:
# shape: (65, 4)
# ┌────────────┬────────────┬───────────┬───────────┐
# │ date       ┆ difference ┆ vola      ┆ norm_diff │
# │ ---        ┆ ---        ┆ ---       ┆ ---       │
# │ date       ┆ f64        ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═══════════╪═══════════╡
# │ 2007-10-12 ┆ -109.51    ┆ 0.160333  ┆ -0.07012  │
# │ 2007-12-21 ┆ -159.36    ┆ 0.171445  ┆ -0.107308 │
# │ 2007-12-28 ┆ -147.16    ┆ 0.1968439 ┆ -0.099595 │
# │ 2008-05-30 ┆ -119.02    ┆ 0.158745  ┆ -0.0851   │
# │ ...        ┆ ...        ┆ ...       ┆ ...       │
# │ 2022-09-09 ┆ -427.7     ┆ 0.204781  ┆ -0.105154 │
# │ 2022-09-16 ┆ -290.26    ┆ 0.246055  ┆ -0.074938 │
# │ 2022-10-14 ┆ 409.86     ┆ 0.2936784 ┆ 0.114388  │
# │ 2023-11-19 ┆ 0.0        ┆ 0.0       ┆ 0.0       │
# └────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# Bei einem Stangle mit Delta(init) von 0,2 spannt sich ein Toleranzbereich von aktuell 380 Punkten (normiert 0,088) auf. Da die Call-Seite weniger Prämie erwirtschaftet, muss hier ein engeres Risikomaß verwendet werden

# %%
st = s.join( t, on: 'date', how: 'outer')
# Out:
# shape: (4479, 5)
# ┌────────────┬──────────┬────────────┬──────┬───────────┐
# │ date       ┆ ref_vola ┆ difference ┆ vola ┆ norm_diff │
# │ ---        ┆ ---      ┆ ---        ┆ ---  ┆ ---       │
# │ date       ┆ f64      ┆ f64        ┆ f64  ┆ f64       │
# ╞════════════╪══════════╪════════════╪══════╪═══════════╡
# │ 2006-01-06 ┆ 0.158745 ┆ null       ┆ null ┆ null      │
# │ 2006-01-09 ┆ 0.1062   ┆ null       ┆ null ┆ null      │
# │ 2006-01-10 ┆ 0.105692 ┆ null       ┆ null ┆ null      │
# │ 2006-01-11 ┆ 0.105169 ┆ null       ┆ null ┆ null      │
# │ ...        ┆ ...      ┆ ...        ┆ ...  ┆ ...       │
# │ 2023-11-03 ┆ 0.132997 ┆ null       ┆ null ┆ null      │
# │ 2023-11-06 ┆ 0.128552 ┆ null       ┆ null ┆ null      │
# │ 2023-11-07 ┆ 0.127107 ┆ null       ┆ null ┆ null      │
# │ 2023-11-19 ┆ null     ┆ 0.0        ┆ 0.0  ┆ 0.0       │
# └────────────┴──────────┴────────────┴──────┴───────────┘

# %%
Vega.lite
  .title( "Ausreisser, statische Betrachtung")
  .data( st )
  .params([
          { name: "opacity", value: 0.5, 
            bind: { input: "range", min: 0, max: 1, step: 0.1 }
          },
          
          ])
  .layer( [{ mark: { type: "bar", color: "#10b981"},
            encoding: { 
                   opacity: { value: { expr: "opacity" }},
                   x: {field: "date", type: "temporal", timeunit: "day"},
                   y: {field: "norm_diff", type: "quantitative",
                       axis: { title: "Monatliche Preisdifferenz (norm.)"}  }
                      } 
            } ,
           { mark: { type: "rule"},
            encoding: { y: { field: "min", aggregate: 'min'},
                             color: { value:'#dc2626'} 
                       }
           },
           { mark: { type: "rule"},
            encoding: { y: { field: "max", aggregate: 'min'},
                             color: { value:'#dc2626'} 
                       }
           },
           { mark: { type: "line", interpolate: 'cardinal', color: 'd6d3d1' },
            encoding: { y: { field: "ref_vola", type: 'quantitative'},
                             color: { value:'#d6d3d1'} ,
                        x: {field: "date", type: "temporal", timeunit: "day"}
                       }
           },
   
          ])
# Out:
# #<Vega::LiteChart:0x00007f77386c9498 @schema="https://vega.github.io/schema/vega-lite/v5.json", @spec={"$schema"=>"https://vega.github.io/schema/vega-lite/v5.json", "width"=>"container", "height"=>"container", "title"=>"Ausreisser, statische Betrachtung", "data"=>{:values=>}, "params"=>, "layer"=>}>

# %%
Vega.lite
  .title( text: "Aussreißer, statische Betrachtung ",
         color: "navy",
        fontSize: 22 ,
  		 align: "center",
  		anchor: "middle",
  			dy: -1,
      baseline: "middle",
  	  subtitle: "S&P 500  (normiert)",
 subtitleColor: "navy", 
subtitleFontSize: 18,
subtitlePadding: 5)
  .data( st )
  .params( [{ name: "opacity", value: 0.5, 
              bind: { input: "range", min: 0, max: 1, step: 0.1 } },
            { name: "barcolor",  value: "#10b981" },
            { name: "linecolor", value: "#d6d3d1" }
           ])
.vconcat( [ {
     resolve: { scale: { y: "independent"} },
     width: 850,
     layer:[ { mark: { type: "bar", color: "#10b981"},
           encoding: { opacity: { value: { expr: "opacity" } },
                             x: { field: "date", 
                                   type: "temporal",
                               timeunit: "day",
                                  scale: { domain: { param: "brush" } }   
                                 },
                             y: { field: "norm_diff", type: "quantitative",
                                   axis: { title: "Monatliche Preisdifferenz (norm.)",
                                          orient: 'left', 
                                            grid: true,
                                      titleColor:  '#0d9488'}
                                  } 
                     }
              } ,
           { mark: { type: "line", interpolate: 'cardinal', color: { expr: "linecolor" }},
                 encoding: { y: { field: "ref_vola", type: 'quantitative',
                              axis: { orient: 'right', 
                                  titleColor: { expr: "linecolor"},
                                      title: "Implied Volatiltiy"},
                                      color: { value: { expr: "linecolor"} } },
                        x: {field: "date", type: "temporal", timeunit: "day",
                            scale: { domain: { param: "brush" } } }
                           }
               } ] 
             } ,
           { 
       width: 850,
      height: 60,
        mark: { type: "bar", color: { expr: "barcolor"} },
      params: [ { name: "brush",
                select: { type: "interval", encodings: ["x"] } }],
    encoding: { x: {field: "date", type: "temporal", timeunit: "day"},
                y: {field: "norm_diff", type: "quantitative",
                     axis: { title: "Events"}  },
          opacity: { value: { expr: "opacity" } },
              } 
            } ]
  )
# Out:
# #<Vega::LiteChart:0x00007f7738c1c0d0 @schema="https://vega.github.io/schema/vega-lite/v5.json", @spec={"$schema"=>"https://vega.github.io/schema/vega-lite/v5.json", "width"=>"container", "height"=>"container", "title"=>{:text=>"Aussreißer, statische Betrachtung ", :color=>"navy", :fontSize=>22, :align=>"center", :anchor=>"middle", :dy=>-1, :baseline=>"middle", :subtitle=>"S&P 500  (normiert)", :subtitleColor=>"navy", :subtitleFontSize=>18, :subtitlePadding=>5}, "data"=>{:values=>}, "params"=>, "vconcat"=>}>
